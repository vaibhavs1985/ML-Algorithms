# %% [markdown]
# # In this notebook, various regression algorithms have been implemented.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import time

# %% [markdown]
# # 1. Linear Regression Closed Form Solution

# %%
#Generate Some random data
X = 2*np.random.rand(1000,1) # Column vector by default
y = 4 + 3*X + np.random.randn(1000,1)

# %%
plt.plot(X,y,'.')

# %% [markdown]
# # The closed form solution is W = (X^T.X)^-1.X^T.y

# %%
# np.c_ concatenates along the column
X_b = np.c_[np.ones((1000,1)),X] # Make x0 = 1
W = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y) # Yields a column vector of shape (2,1)

W
# Out:
# array([[4.0005635 ],
#        [3.04359376]])

# %%
y_pred = X_b.dot(W)

# %%
plt.plot(X,y,'.')
plt.plot(X,y_pred,'-')

# %% [markdown]
# # Time for closed form solution with varying dimensions (N) of X (Complexity : O(N^3) )

# %%
Dim = []
time_closed = []
for N in range(100,100000,200):
    X = 2*np.random.rand(N,1) 
    y = 4 + 3*X + np.random.randn(N,1)
    X_b = np.c_[np.ones((N,1)),X] 
    tic = time.perf_counter()
    W = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y) 
    toc = time.perf_counter()
    Dim.append(N)
    diff = toc - tic
    time_closed.append(diff*1000) # Adding time in ms

# %%
plt.plot(Dim,time_closed,'--')
plt.xlabel('Dimensions')
plt.ylabel('Time in ms')
# Out:
# Text(0, 0.5, 'Time in ms')

# %% [markdown]
# # 2. Batch Gradient Descent

# %%
X = 2*np.random.rand(1000,1) # Column vector by default
y = 4 + 3*X + np.random.randn(1000,1)
X_b = np.c_[np.ones((1000,1)),X] # Make x0 = 1

# %%
learning_rate = 0.1
iterations = 10000
#W = np.zeros((2,1))
W = np.random.rand(2,1)
for i in range(iterations):
    W = W - (2/1000)*learning_rate*(X_b.T.dot(X_b.dot(W)- y))

W
# Out:
# array([[3.9029299 ],
#        [3.03881955]])
